# %%
import json 
import pandas as pd 
import numpy as np 
import pylab as plt 
import networkx as nx

# %%
def loadjson(fname):
    with open(fname, 'r') as fdata:
        res = json.load(fdata)

    res = {key: val['order'] for key, val in res.items()}
    
    return res

# %%
resnames = ["norm","minopt", "sheppard", "sheppardscale", "raw", "kruskal", "unitball"]
dicts = dict(zip(
    resnames,
    [loadjson(f"results/{s}-results.json") for s in resnames]
))
df = pd.DataFrame(dicts)
df.head()
# Out:
#                    normalized-stress        minopt      sheppard  \
# 130bit                  [A0, A1, A2]  [A0, A1, A2]  [A2, A1, A0]
# 130bit_factor_base      [A0, A2, A1]  [A0, A2, A1]  [A2, A1, A0]
# 130bit_solution         [A0, A2, A1]  [A0, A2, A1]  [A2, A1, A0]
# 494_bus                 [A0, A2, A1]  [A0, A1, A2]  [A2, A1, A0]
# 662_bus                 [A0, A2, A1]  [A0, A1, A2]  [A2, A1, A0]
#
#                    sheppardscale           raw       kruskal      unitball
# 130bit              [A0, A1, A2]  [A0, A1, A2]  [A0, A1, A2]  [A1, A0, A2]
# 130bit_factor_base  [A0, A2, A1]  [A0, A2, A1]  [A0, A2, A1]  [A0, A1, A2]
# 130bit_solution     [A0, A2, A1]  [A0, A2, A1]  [A0, A2, A1]  [A0, A1, A2]
# 494_bus             [A0, A1, A2]  [A0, A2, A1]  [A0, A1, A2]  [A1, A0, A2]
# 662_bus             [A0, A1, A2]  [A0, A2, A1]  [A0, A1, A2]  [A1, A0, A2]

# %%
df['sheppard'] = df["sheppard"].apply(lambda x: list(reversed(x)) if isinstance(x, list) else x)

# %%
df.to_csv("out-results.csv")

# %%
for col in df.columns:
    print(df[col])
# Out:
# random-last                                                                0.0
# oscil_dcop_56                      [stress, tsnet, random, sfdp, neato, twopi]
# bp_600                             [stress, random, tsnet, neato, twopi, sfdp]
# G6                                 [stress, random, neato, tsnet, twopi, sfdp]
# cage_G_38                          [stress, tsnet, random, neato, twopi, sfdp]
#                                                       ...
# dynamicSoaringProblem_1_mapping    [stress, random, twopi, neato, sfdp, tsnet]
# oscil_dcop_08_b                    [stress, random, tsnet, twopi, neato, sfdp]
# lnsp_511                           [stress, random, tsnet, sfdp, neato, twopi]
# dwa512                             [stress, random, tsnet, sfdp, neato, twopi]
# lp_beaconfd                        [stress, random, tsnet, neato, twopi, sfdp]
# Name: normalized-stress, Length: 1117, dtype: object
# random-last                                                           0.673835
# oscil_dcop_56                      [stress, neato, sfdp, tsnet, twopi, random]
# bp_600                             [stress, neato, sfdp, tsnet, twopi, random]
# G6                                 [stress, neato, sfdp, random, twopi, tsnet]
# cage_G_38                          [stress, neato, sfdp, tsnet, twopi, random]
#                                                       ...
# dynamicSoaringProblem_1_mapping    [neato, stress, sfdp, random, twopi, tsnet]
# oscil_dcop_08_b                    [neato, stress, sfdp, twopi, random, tsnet]
# lnsp_511                           [stress, neato, sfdp, tsnet, twopi, random]
# dwa512                             [stress, neato, sfdp, tsnet, twopi, random]
# lp_beaconfd                        [stress, neato, sfdp, tsnet, twopi, random]
# Name: minopt, Length: 1117, dtype: object
# random-last                                                           0.853943
# oscil_dcop_56                      [stress, neato, sfdp, tsnet, twopi, random]
# bp_600                             [stress, neato, sfdp, tsnet, twopi, random]
# G6                                 [stress, sfdp, neato, twopi, tsnet, random]
# cage_G_38                          [tsnet, neato, stress, sfdp, twopi, random]
#                                                       ...
# dynamicSoaringProblem_1_mapping    [sfdp, neato, stress, twopi, random, tsnet]
# oscil_dcop_08_b                    [sfdp, neato, stress, tsnet, twopi, random]
# lnsp_511                           [stress, neato, sfdp, tsnet, twopi, random]
# dwa512                             [stress, neato, sfdp, tsnet, twopi, random]
# lp_beaconfd                        [sfdp, stress, neato, tsnet, twopi, random]
# Name: sheppard, Length: 1117, dtype: object
# random-last                                                           0.008961
# oscil_dcop_56                      [twopi, neato, random, sfdp, stress, tsnet]
# bp_600                             [sfdp, twopi, neato, random, tsnet, stress]
# G6                                 [sfdp, tsnet, twopi, neato, random, stress]
# cage_G_38                          [sfdp, twopi, neato, tsnet, random, stress]
#                                                       ...
# dynamicSoaringProblem_1_mapping    [tsnet, sfdp, neato, twopi, stress, random]
# oscil_dcop_08_b                    [sfdp, neato, twopi, tsnet, stress, random]
# lnsp_511                           [twopi, neato, sfdp, random, tsnet, stress]
# dwa512                             [twopi, neato, sfdp, random, tsnet, stress]
# lp_beaconfd                        [sfdp, twopi, neato, random, tsnet, stress]
# Name: sheppardscale, Length: 1117, dtype: object
# random-last                                                                0.0
# oscil_dcop_56                      [stress, tsnet, random, sfdp, neato, twopi]
# bp_600                             [stress, random, tsnet, neato, twopi, sfdp]
# G6                                 [stress, random, neato, tsnet, twopi, sfdp]
# cage_G_38                          [stress, tsnet, random, neato, twopi, sfdp]
#                                                       ...
# dynamicSoaringProblem_1_mapping    [stress, random, twopi, neato, sfdp, tsnet]
# oscil_dcop_08_b                    [stress, random, tsnet, twopi, neato, sfdp]
# lnsp_511                           [stress, random, tsnet, sfdp, neato, twopi]
# dwa512                             [stress, random, tsnet, sfdp, neato, twopi]
# lp_beaconfd                        [stress, random, tsnet, neato, twopi, sfdp]
# Name: raw, Length: 1117, dtype: object
# random-last                                                           0.655914
# oscil_dcop_56                      [stress, neato, sfdp, tsnet, twopi, random]
# bp_600                             [stress, neato, sfdp, tsnet, twopi, random]
# G6                                 [stress, neato, sfdp, random, twopi, tsnet]
# cage_G_38                          [stress, neato, twopi, sfdp, tsnet, random]
#                                                       ...
# dynamicSoaringProblem_1_mapping    [neato, stress, sfdp, random, twopi, tsnet]
# oscil_dcop_08_b                    [neato, stress, sfdp, random, twopi, tsnet]
# lnsp_511                           [stress, neato, sfdp, tsnet, twopi, random]
# dwa512                             [stress, neato, sfdp, tsnet, twopi, random]
# lp_beaconfd                        [stress, neato, sfdp, tsnet, twopi, random]
# Name: kruskal, Length: 1117, dtype: object
# random-last                                                           0.374552
# oscil_dcop_56                      [stress, tsnet, neato, sfdp, twopi, random]
# bp_600                             [tsnet, stress, twopi, random, neato, sfdp]
# G6                                 [tsnet, stress, twopi, random, neato, sfdp]
# cage_G_38                          [stress, twopi, neato, sfdp, random, tsnet]
#                                                       ...
# dynamicSoaringProblem_1_mapping    [stress, twopi, neato, random, sfdp, tsnet]
# oscil_dcop_08_b                    [stress, tsnet, twopi, neato, sfdp, random]
# lnsp_511                           [tsnet, stress, sfdp, twopi, neato, random]
# dwa512                             [stress, tsnet, random, sfdp, twopi, neato]
# lp_beaconfd                        [tsnet, stress, random, twopi, neato, sfdp]
# Name: unitball, Length: 1117, dtype: object
