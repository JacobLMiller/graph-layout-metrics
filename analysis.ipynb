# %%
import json 
import pandas as pd 
import numpy as np 
import pylab as plt 
import networkx as nx

# %%
def loadjson(fname):
    with open(fname, 'r') as fdata:
        res = json.load(fdata)

    res = {key: val['order'] for key, val in res.items()}
    
    return res

# %%
resnames = ["norm","minopt", "sheppard", "sheppardscale", "raw", "kruskal", "unitball"]
dicts = dict(zip(
    resnames,
    [loadjson(f"results/{s}-results.json") for s in resnames]
))
df = pd.DataFrame(dicts)
df.head()
# Out:
#                                                            norm  \
# 130bit              [stress, tsnet, random, neato, twopi, sfdp]
# 130bit_factor_base  [stress, random, tsnet, twopi, neato, sfdp]
# 130bit_solution     [stress, random, tsnet, twopi, neato, sfdp]
# 494_bus             [stress, random, tsnet, sfdp, neato, twopi]
# 662_bus             [stress, random, tsnet, sfdp, neato, twopi]
#
#                                                          minopt  \
# 130bit              [stress, neato, sfdp, tsnet, twopi, random]
# 130bit_factor_base  [neato, stress, sfdp, twopi, random, tsnet]
# 130bit_solution     [neato, stress, sfdp, twopi, random, tsnet]
# 494_bus             [stress, neato, sfdp, tsnet, twopi, random]
# 662_bus             [stress, neato, sfdp, tsnet, twopi, random]
#
#                                                        sheppard  \
# 130bit              [random, twopi, tsnet, sfdp, neato, stress]
# 130bit_factor_base  [random, tsnet, stress, neato, sfdp, twopi]
# 130bit_solution     [random, tsnet, twopi, stress, neato, sfdp]
# 494_bus             [random, twopi, tsnet, sfdp, neato, stress]
# 662_bus             [random, twopi, tsnet, sfdp, neato, stress]
#
#                                                   sheppardscale  \
# 130bit              [stress, neato, sfdp, tsnet, random, twopi]
# 130bit_factor_base  [twopi, neato, stress, sfdp, random, tsnet]
# 130bit_solution     [twopi, neato, stress, sfdp, random, tsnet]
# 494_bus             [stress, neato, sfdp, tsnet, twopi, random]
# 662_bus             [neato, sfdp, stress, tsnet, twopi, random]
#
#                                                             raw  \
# 130bit              [stress, tsnet, random, neato, twopi, sfdp]
# 130bit_factor_base  [stress, random, tsnet, twopi, neato, sfdp]
# 130bit_solution     [stress, random, tsnet, twopi, neato, sfdp]
# 494_bus             [stress, random, tsnet, sfdp, neato, twopi]
# 662_bus             [stress, random, tsnet, sfdp, neato, twopi]
#
#                                                         kruskal  \
# 130bit              [stress, neato, sfdp, tsnet, random, twopi]
# 130bit_factor_base  [neato, stress, sfdp, random, twopi, tsnet]
# 130bit_solution     [neato, stress, sfdp, random, twopi, tsnet]
# 494_bus             [stress, neato, sfdp, tsnet, twopi, random]
# 662_bus             [stress, neato, sfdp, tsnet, twopi, random]
#
#                                                        unitball
# 130bit              [tsnet, stress, twopi, random, sfdp, neato]
# 130bit_factor_base  [stress, tsnet, twopi, neato, random, sfdp]
# 130bit_solution     [stress, tsnet, twopi, neato, sfdp, random]
# 494_bus             [tsnet, stress, twopi, random, sfdp, neato]
# 662_bus             [tsnet, stress, twopi, random, sfdp, neato]

# %%
df['sheppard'] = df["sheppard"].apply(lambda x: list(reversed(x)) if isinstance(x, list) else x)

# %%
df.to_csv("out-results.csv")

# %%
for col in df.columns:
    print(df[col])
# Out:
# 130bit                [stress, tsnet, random, neato, twopi, sfdp]
# 130bit_factor_base    [stress, random, tsnet, twopi, neato, sfdp]
# 130bit_solution       [stress, random, tsnet, twopi, neato, sfdp]
# 494_bus               [stress, random, tsnet, sfdp, neato, twopi]
# 662_bus               [stress, random, tsnet, sfdp, neato, twopi]
#                                          ...
# young4c               [stress, tsnet, random, sfdp, neato, twopi]
# zed                   [stress, random, tsnet, neato, twopi, sfdp]
# zed_b                 [stress, random, tsnet, twopi, neato, sfdp]
# zed_c                 [stress, random, twopi, neato, tsnet, sfdp]
# zed_hi                [stress, random, twopi, neato, tsnet, sfdp]
# Name: norm, Length: 1115, dtype: object
# 130bit                [stress, neato, sfdp, tsnet, twopi, random]
# 130bit_factor_base    [neato, stress, sfdp, twopi, random, tsnet]
# 130bit_solution       [neato, stress, sfdp, twopi, random, tsnet]
# 494_bus               [stress, neato, sfdp, tsnet, twopi, random]
# 662_bus               [stress, neato, sfdp, tsnet, twopi, random]
#                                          ...
# young4c               [neato, stress, tsnet, sfdp, twopi, random]
# zed                   [stress, neato, sfdp, tsnet, twopi, random]
# zed_b                 [stress, neato, sfdp, twopi, tsnet, random]
# zed_c                 [neato, stress, sfdp, twopi, tsnet, random]
# zed_hi                [stress, neato, sfdp, twopi, random, tsnet]
# Name: minopt, Length: 1115, dtype: object
# 130bit                [stress, neato, sfdp, tsnet, twopi, random]
# 130bit_factor_base    [twopi, sfdp, neato, stress, tsnet, random]
# 130bit_solution       [sfdp, neato, stress, twopi, tsnet, random]
# 494_bus               [stress, neato, sfdp, tsnet, twopi, random]
# 662_bus               [stress, neato, sfdp, tsnet, twopi, random]
#                                          ...
# young4c               [stress, neato, tsnet, sfdp, twopi, random]
# zed                   [sfdp, stress, neato, tsnet, twopi, random]
# zed_b                 [twopi, tsnet, sfdp, neato, stress, random]
# zed_c                 [sfdp, neato, twopi, stress, random, tsnet]
# zed_hi                [neato, sfdp, twopi, stress, tsnet, random]
# Name: sheppard, Length: 1115, dtype: object
# 130bit                [stress, neato, sfdp, tsnet, random, twopi]
# 130bit_factor_base    [twopi, neato, stress, sfdp, random, tsnet]
# 130bit_solution       [twopi, neato, stress, sfdp, random, tsnet]
# 494_bus               [stress, neato, sfdp, tsnet, twopi, random]
# 662_bus               [neato, sfdp, stress, tsnet, twopi, random]
#                                          ...
# young4c               [neato, stress, tsnet, sfdp, twopi, random]
# zed                   [neato, stress, sfdp, tsnet, twopi, random]
# zed_b                 [twopi, tsnet, stress, neato, sfdp, random]
# zed_c                 [twopi, stress, neato, sfdp, tsnet, random]
# zed_hi                [twopi, stress, neato, sfdp, random, tsnet]
# Name: sheppardscale, Length: 1115, dtype: object
# 130bit                [stress, tsnet, random, neato, twopi, sfdp]
# 130bit_factor_base    [stress, random, tsnet, twopi, neato, sfdp]
# 130bit_solution       [stress, random, tsnet, twopi, neato, sfdp]
# 494_bus               [stress, random, tsnet, sfdp, neato, twopi]
# 662_bus               [stress, random, tsnet, sfdp, neato, twopi]
#                                          ...
# young4c               [stress, tsnet, random, sfdp, neato, twopi]
# zed                   [stress, random, tsnet, neato, twopi, sfdp]
# zed_b                 [stress, random, tsnet, twopi, neato, sfdp]
# zed_c                 [stress, random, twopi, neato, tsnet, sfdp]
# zed_hi                [stress, random, twopi, neato, tsnet, sfdp]
# Name: raw, Length: 1115, dtype: object
# 130bit                [stress, neato, sfdp, tsnet, random, twopi]
# 130bit_factor_base    [neato, stress, sfdp, random, twopi, tsnet]
# 130bit_solution       [neato, stress, sfdp, random, twopi, tsnet]
# 494_bus               [stress, neato, sfdp, tsnet, twopi, random]
# 662_bus               [stress, neato, sfdp, tsnet, twopi, random]
#                                          ...
# young4c               [stress, neato, tsnet, sfdp, random, twopi]
# zed                   [stress, neato, sfdp, tsnet, twopi, random]
# zed_b                 [neato, stress, sfdp, twopi, tsnet, random]
# zed_c                 [sfdp, neato, stress, twopi, tsnet, random]
# zed_hi                [stress, neato, sfdp, twopi, random, tsnet]
# Name: kruskal, Length: 1115, dtype: object
# 130bit                [tsnet, stress, twopi, random, sfdp, neato]
# 130bit_factor_base    [stress, tsnet, twopi, neato, random, sfdp]
# 130bit_solution       [stress, tsnet, twopi, neato, sfdp, random]
# 494_bus               [tsnet, stress, twopi, random, sfdp, neato]
# 662_bus               [tsnet, stress, twopi, random, sfdp, neato]
#                                          ...
# young4c               [tsnet, stress, sfdp, neato, random, twopi]
# zed                   [tsnet, stress, random, twopi, neato, sfdp]
# zed_b                 [stress, twopi, sfdp, neato, random, tsnet]
# zed_c                 [tsnet, stress, twopi, sfdp, neato, random]
# zed_hi                [stress, tsnet, twopi, neato, sfdp, random]
# Name: unitball, Length: 1115, dtype: object
